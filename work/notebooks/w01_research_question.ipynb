# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/flyrank-bih/flyrank-ml-internship-starter/blob/main/work/notebooks/w01_research_question.ipynb)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# ### Lane: Content Refresh Prioritization
#
# I am working on the Content Refresh lane. The objective is to identify content pages that should be refreshed first using historical search and engagement metrics. This problem is valuable because content teams have limited time and cannot update every page. Prioritizing the highest-impact pages can improve efficiency and potential organic traffic.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# ### Research Question
#
# Which content pages should be prioritized for refreshing based on historical performance data?
#
# Decision:
# Recommend whether a page should be placed in the refresh queue.
#
# Who acts on it?
# SEO managers and content editors.
#
# Cost of a wrong call:
# If a low-value page is selected, time and resources are wasted. If a high-potential page is missed, the business may lose opportunities to improve search traffic and user engagement.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import pandas as pd

df = pd.read_csv("../../data/raw/content_refresh_anonymized.csv")

print("Rows:", df.shape[0])
print("Columns:", df.shape[1])

print("\nAverage 90-day impressions:", round(df["impressions_90d"].mean(), 2))
print("Average 90-day clicks:", round(df["clicks_90d"].mean(), 2))
print("Average content age:", round(df["content_age_days"].mean(), 2))
# Out:
# Rows: 30000
# Columns: 44
#
# Average 90-day impressions: 5200.37
# Average 90-day clicks: 16.1
# Average content age: 256.17

# %% [markdown]
# The starter dataset contains **XXXX** pages and **XX** features.
#
# Average 90-day impressions: **XXXX**
#
# Average 90-day clicks: **XXX**
#
# Average content age: **XXX days**
#
# These numbers indicate there is sufficient variation to investigate which pages are likely candidates for a content refresh.

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# This work provides decision support based on observed historical data. It can identify patterns that are associated with content performance and help prioritize pages for review.
#
# This project does not prove that refreshing a page will increase rankings or traffic. It cannot predict Google's ranking decisions or establish causal relationships.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
