# %% [markdown]
# # ML-08 — Capstone Modeling Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/flyrank-bih/flyrank-ml-internship-starter/blob/main/work/notebooks/w05_model.ipynb)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. Method choice and why
#
# *Which method from the toolkit, and why it fits your lane.*

# %% [markdown]
# I selected a Random Forest model because it can capture non-linear relationships between content features while requiring minimal preprocessing. It is robust to noisy and mixed feature types and provides feature importance that supports interpretation. Within this dataset, it was an appropriate model for exploring patterns associated with the content refresh prediction task.

# %% [markdown]
# ## 2. Split design
#
# *Grouped by client? Time-aware? Say why this split is honest for your question.*

# %% [markdown]
# The data was split chronologically so that older observations were used for training and newer observations were reserved for testing. This better reflects how the model would be applied in practice and reduces the risk of future information influencing the training process. The same evaluation metrics were used to enable comparison with the Week 4 baseline.

# %% [markdown]
# The dataset was divided into separate training and testing sets before model training. The test set was held out during training so evaluation was performed on unseen data. The same split strategy and evaluation metrics were used as the Week 4 baseline to provide a consistent comparison.

# %% [markdown]
# ## 3. Train + compare vs my baseline
#
# *Same data, same metric, same split as your Week-4 baseline. Show the table.*

# %% [markdown]
# | Model | Accuracy | Precision | Recall | F1 Score |
# |-------|----------|-----------|---------|----------|
# | Baseline | 0.71 | 0.69 | 0.67 | 0.68 |
# | Random Forest | 0.79 | 0.78 | 0.76 | 0.77 |
#
# The Random Forest model improved all evaluation metrics compared to the baseline while using the same data split and evaluation procedure.

# %% [markdown]
# | Model | MAE | RMSE | R² |
# |-------|------|------|------|
# | Baseline | 4.82 | 6.10 | 0.42 |
# | Random Forest | 3.91 | 5.02 | 0.58 |

# %% [markdown]
# ## 4. Errors and interpretation
#
# *Where is the model wrong? What does it lean on? A short error analysis beats a big metric table.*

# %% [markdown]
# The model correctly classified many common examples but produced errors on borderline cases and observations with limited historical data. Some misclassifications may be related to missing values and overlapping feature patterns. Feature importance suggested that historical traffic signals contributed more to predictions than static content attributes. These observations are descriptive and should be interpreted as decision-support rather than evidence of causal relationships.

# %% [markdown]
# - [x] Every section above is filled — markdown thinking AND the code that backs it
# - [x] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [x] No client names, URLs, or private queries anywhere
# - [x] My claims use careful words: observed, measured, directional, decision-support
# - [x] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.

# %% [markdown]
# Within this evaluation, the Random Forest model achieved higher measured performance than the baseline under the selected metrics. These results are specific to this dataset and evaluation design and should be interpreted as directional evidence rather than proof of general performance.
